# %%
import pandas as pd
import seaborn as sns

# %%
data = pd.read_excel('excel.xlsx')
data.columns = data.columns.str.strip()
# # 3. Now run your filter using the clean column name
# filtered_data = data[data['Job Title'] == 'Sr.Manger']


new_column_values = [1, 2, 3, 4, 5, 6, 7, None, 9, 10]
row_count = len(data)
if len(new_column_values) < row_count:
    # Fill the remaining rows with empty values if your dataset is longer than 10 rows
    new_column_values += [None] * (row_count - len(new_column_values))
else:
    # Trim the list if your dataset has fewer than 10 rows
    new_column_values = new_column_values[:row_count]

# 3. Insert the column at a specific position (e.g., at index 0 for the very first column)
# Syntax: data.insert(loc, column_name, value_list)
data.insert(0, 'Sequence_ID', new_column_values)
print(data.isnull().sum())
# Out:
# Sequence_ID      991
# EEID               0
# Full Name          0
# Job Title          0
# Department         0
# Business Unit      0
# Gender             0
# Ethnicity          0
# Age                0
# Hire Date          0
# Annual Salary      0
# Bonus %            0
# Country            0
# City               0
# Exit Date        915
# dtype: int64

# %%
new.shape
# Out:
# (1000, 14)

# %%
# new.head(10)
# new.tail(20)
# new.info().shape
# new.describe()
# new.scatter(data='excel.xlsx',x='Full Name',y='Age')

# %%
# data[['Gender','Age','Annual Salary','City']].head(8)
data.iloc[[1,2,5,3]]
# Out:
#      EEID        Full Name                 Job Title Department  \
# 1  E04105    Theodore Dinh       Technical Architect         IT
# 2  E02572     Luna Sanders                  Director    Finance
# 5  E00644     Joshua Gupta    Account Representative      Sales
# 3  E02832  Penelope Jordan  Computer Systems Manager         IT
#
#          Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# 1        Manufacturing    Male      Asian   59 1997-11-29          99975
# 2  Speciality Products  Female  Caucasian   50 2006-10-26         163099
# 5            Corporate    Male      Asian   57 2017-01-24          50994
# 3        Manufacturing  Female  Caucasian   26 2019-09-27          84913
#
#    Bonus %        Country       City Exit Date
# 1     0.00          China  Chongqing       NaT
# 2     0.20  United States    Chicago       NaT
# 5     0.00          China  Chongqing       NaT
# 3     0.07  United States    Chicago       NaT
