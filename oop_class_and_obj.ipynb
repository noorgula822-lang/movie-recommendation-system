# %%
class Atm:
    def __init__(self):
        self.name=''
        self.balance=''
        self.account_name=''
        self.menu()
        self.amount()
        self.coountry()
        self.age()
    

    def menu(self):
        user_name=input(str(
           """
           ENTER USER NAME:
           """
        ))
    def amount(self):
         user_amount=input(
             ''''
             ENTER AMOUNT
             '''
         )
        
    def coountry(self):
         user_country=input(
             ''''
             SELECT COUNTRY
             '''
         )
    def age(self):
         user_country=input(
             ''''
             ENTER YOUR AGE HERE!
             '''
         )


     
obj=Atm()
# Out:
#            ENTER USER NAME:
#             zakir
# '
#              ENTER AMOUNT
#               100
# '
#              SELECT COUNTRY
#               xsm
# '
#              ENTER YOUR AGE HERE!
#               sxs

# %%
from flask import Flask

app = Flask(__name__)


@app.route("/")
def home():
    return """
    <html>
    <body>

    <h1>Hello World</h1>
    <h2>This is Python output on webpage</h2>

    </body>
    </html>
    """


app.run(port=50001)
